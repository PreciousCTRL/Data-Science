# %%
import pandas as pd
import numpy as np

# %%
sub = pd.read_csv('../data/table_VFL_2026_TEST_SET.csv')

sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14200 entries, 0 to 14199
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ENCOUNTER_KEY          14200 non-null  int64
#  1   PATIENT_NUMBER         14200 non-null  int64
#  2   DOCTOR                 14200 non-null  int64
#  3   ICU_DAYS               14200 non-null  int64
#  4   DEPARTMENT             14200 non-null  object
#  5   DISCHARGED_TO          14200 non-null  object
#  6   STANDARD_ORDERS_USED   14200 non-null  object
#  7   NUM_CHRONIC_COND       14200 non-null  object
#  8   DISCH_NURSE_ID         14200 non-null  int64
#  9   ORDER_SET_USED         14200 non-null  int64
#  10  ORDER_TOTAL_CHARGES    14200 non-null  int64
#  11  GENDER                 14200 non-null  object
#  12  ZIP                    14200 non-null  int64
#  13  STATECODE              14200 non-null  object
# ...
